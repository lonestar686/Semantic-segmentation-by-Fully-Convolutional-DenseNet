# %% [markdown]
# #  Semantic segmentation by Fully Convolutional DenseNet56 with Keras2.0

# %% [markdown]
# ###  This is my experiment to see how Fully Convolutional DenseNet56 works with little data

# %% [markdown]
# For theory and algorithm. please refer to "The One Hundred Layers Tiramisu: Fully Convolutional DenseNets for Semantic Segmentation (Simon Jegou, Michal Drozdzal, David Vazquez, Adriana Romero, Yoshua Bengio),  5 Dec 2016"
# https://arxiv.org/abs/1611.09326
#
# Origingal code in fast.ai by Jeremy Howard is provided with this link. I rewrite it with keras2 and modify https://github.com/fastai/courses/blob/master/deeplearning2/tiramisu-keras.ipynb
#
# For data, http://mi.eng.cam.ac.uk/research/projects/VideoRec/CamVid/
# Segmentation and Recognition Using Structure from Motion Point Clouds, ECCV 2008 Brostow, Shotton, Fauqueur, Cipolla

# %%
import os
import h5py
import numpy as np
import time
import glob
import json
import csv
import bcolz
import threading
import random
from PIL import Image
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

import keras

# check keras information
print(keras.__version__, keras.__file__)

# tensorflow information
import tensorflow as tf
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
print(tf.__version__, tf.__file__)

#
from keras import applications
from keras.preprocessing import image

from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D,Cropping2D,BatchNormalization,Conv2DTranspose
from keras.layers import Activation, Dropout, Flatten, Dense, Lambda, GlobalAveragePooling2D, Reshape
from keras.utils.np_utils import to_categorical
from keras.models import Model,Sequential

from keras.engine import Input
from keras.layers.merge import concatenate
from keras.layers.pooling import AveragePooling2D
from keras.regularizers import l2
from keras.utils import np_utils
from keras.optimizers import SGD
# Out:
# /home/hzh/anaconda3/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# 2.1.3 /home/hzh/anaconda3/lib/python3.5/site-packages/keras/__init__.py
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 5535124165356163200
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 7239188480
# locality {
#   bus_id: 1
# }
# incarnation: 17761682366134232474
# physical_device_desc: "device: 0, name: Quadro K5100M, pci bus id: 0000:01:00.0, compute capability: 3.0"
# ]
# 1.4.1 /home/hzh/anaconda3/lib/python3.5/site-packages/tensorflow/__init__.py

# %% [markdown]
# ## 1. Data preparation

# %% [markdown]
# CamVid., sciene-images data set, is used.

# %%
PATH='./data/camvid/'

# %% [markdown]
# ### 1.1  Read name of images

# %%
frames_path = PATH+'701_StillsRaw_full/'

# %%
labels_path = PATH+'LabeledApproved_full/'

# %%
fnames = glob.glob(frames_path+'*.png')

# %%
lnames = [labels_path+os.path.basename(fn)[:-4]+'_L.png' for fn in fnames]
print(len(fnames), len(lnames))
# Out:
# 701 701

# %%
img_sz = (480,360)

# %%
def open_image(fn): return np.array(Image.open(fn).resize(img_sz, Image.NEAREST))

# %%
img = Image.open(fnames[0]).resize(img_sz, Image.NEAREST)

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=480x360 at 0x7FF2610EFC18>

# %%
img0 = np.array(img)
img0.shape
# Out:
# (360, 480, 3)

# %%
# original image
img1 = Image.open(fnames[0])
img1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=960x720 at 0x7FF2610482B0>

# %%
img10 = np.array(img1)
img10.shape
# Out:
# (720, 960, 3)

# %% [markdown]
# ### 1.2 Load images

# %%
imgs = np.stack([open_image(fn) for fn in fnames])

# %%
labels = np.stack([open_image(fn) for fn in lnames])

# %%
imgs.shape,labels.shape
# Out:
# ((701, 360, 480, 3), (701, 360, 480, 3))

# %% [markdown]
# ### 1.3 Save array

# %%
def save_array(fname, arr):
    c=bcolz.carray(arr, rootdir=fname, mode='w')
    c.flush()

def load_array(fname): return bcolz.open(fname)[:]

# %%
#Normalize pixel values
imgs=imgs/255.

# %%
# need to make a directory
results_directory = 'results'
try:
    os.stat(PATH+results_directory)
except:
    os.mkdir(PATH+results_directory)
#
save_array(PATH+results_directory+'/imgs.bc', imgs)
save_array(PATH+results_directory+'/labels.bc', labels)

# %%
imgs = load_array(PATH+results_directory+'/imgs.bc')
labels = load_array(PATH+results_directory+'/labels.bc')

# %% [markdown]
# ### 1.4 Standardize values of image data

# %%
av=np.mean(imgs)
sd=np.std(imgs)
av,sd
# Out:
# (0.39996644266360865, 0.3017949114229099)

# %%
imgs-=av
imgs/=sd

# %%
n,r,c,ch = imgs.shape

# %%
#input_shape = (224,224,3)
input_shape = (256,256,3)
nrows, ncols, nchs = input_shape

# %% [markdown]
# ## 2.Data Preprocessing

# %% [markdown]
# ### 2.1 Data generator

# %% [markdown]
# This implementation employs data augmentation on CamVid.
#
# Augmentation includes random cropping / horizontal flipping, as done by `segm_generator()`. `BatchIndices()` lets us randomly sample batches from input array.

# %%
class BatchIndices(object):
    def __init__(self, n, bs, shuffle=False):
        self.n,self.bs,self.shuffle = n,bs,shuffle
        self.lock = threading.Lock()
        self.reset()

    def reset(self):
        self.idxs = (np.random.permutation(self.n) 
                     if self.shuffle else np.arange(0, self.n))
        self.curr = 0

    def __next__(self):
        with self.lock:
            if self.curr >= self.n: self.reset()
            ni = min(self.bs, self.n-self.curr)
            res = self.idxs[self.curr:self.curr+ni]
            self.curr += ni
            return res

# %%
bi = BatchIndices(10,3)
[next(bi) for o in range(5)]
# Out:
# [array([0, 1, 2]),
#  array([3, 4, 5]),
#  array([6, 7, 8]),
#  array([9]),
#  array([0, 1, 2])]

# %%
bi = BatchIndices(10,3,True)
[next(bi) for o in range(5)]
# Out:
# [array([0, 7, 4]),
#  array([5, 9, 3]),
#  array([2, 8, 6]),
#  array([1]),
#  array([2, 4, 0])]

# %%
class segm_generator(object):
    def __init__(self, x, y, bs=64, out_sz=(nrows,ncols), train=True):
        self.x, self.y, self.bs, self.train = x,y,bs,train
        self.n, self.ri, self.ci, _ = x.shape
        self.idx_gen = BatchIndices(self.n, bs, train)
        self.ro, self.co = out_sz
        self.ych = self.y.shape[-1] if len(y.shape)==4 else 1

    def get_slice(self, i,o):
        start = random.randint(0, i-o) if self.train else (i-o)
        return slice(start, start+o)

    def get_item(self, idx):
        slice_r = self.get_slice(self.ri, self.ro)
        slice_c = self.get_slice(self.ci, self.co)
        x = self.x[idx, slice_r, slice_c]
        y = self.y[idx, slice_r, slice_c]
        if self.train and (random.random()>0.5): 
            y = y[:,::-1]
            x = x[:,::-1]
        return x, y

    def __next__(self):
        idxs = next(self.idx_gen)
        items = (self.get_item(idx) for idx in idxs)
        xs,ys = zip(*items)
        return np.stack(xs), np.stack(ys).reshape(len(ys), -1, self.ych)

# %% [markdown]
# As an example, here's a crop of the image.

# %%
sg = segm_generator(imgs, labels, 4, train=False)
b_img, b_label = next(sg)
plt.imshow(b_img[0]*0.3+0.4);

# %%
plt.imshow(imgs[0]*0.3+0.4);

# %%
sg = segm_generator(imgs, labels, 4, train=True)
b_img, b_label = next(sg)
plt.imshow(b_img[0]*0.3+0.4);

# %% [markdown]
# ### 2.2 Convert labels

# %% [markdown]
# The following loads, parses, and converts the segment labels we need for targets.
#
# In particular we're looking to make the segmented targets into integers for classification purposes.

# %% [markdown]
# Each segment / category is indicated by a particular color. The following maps each unique pixel to it's category.

# %%
for l in open(PATH+"label_colors.txt"):
    aa = l[:-1].split("\t")
    a=aa[0]
    b=aa[1]
    print(aa)
# Out:
# ['64 128 64', 'Animal']
# ['192 0 128', 'Archway']
# ['0 128 192', 'Bicyclist']
# ['0 128 64', 'Bridge']
# ['128 0  0', 'Building']
# ['64 0 128', 'Car']
# ['64 0 192', 'CartLuggagePram']
# ['192 128 64', 'Child']
# ['192 192 128', 'Column_Pole']
# ['64 64 128', 'Fence']
# ['128 0 192', 'LaneMkgsDriv']
# ['192 0 64', 'LaneMkgsNonDriv']
# ['128 128 64', 'Misc_Text']
# ['192 0 192', 'MotorcycleScooter']
# ['128 64 64', 'OtherMoving']
# ['64 192 128', 'ParkingBlock']
# ['64 64  0', 'Pedestrian']
# ['128 64 128', 'Road']
# ['128 128 192', 'RoadShoulder']
# ['0 0  192', 'Sidewalk']
# ['192 128 128', 'SignSymbol']
# ['128 128 128', 'Sky']
# ['64 128 192', 'SUVPickupTruck']
# ['0 0   64', 'TrafficCone']
# ['0 64  64', 'TrafficLight']
# ['192 64 128', 'Train']
# ['128 128 0', 'Tree']
# ['192 128 192', 'Truck_Bus']
# ['64 0  64', 'Tunnel']
# ['192 192 0', 'VegetationMisc']
# ['0 0    0', 'Void']
# ['64 192 0', 'Wall']

# %%
def parse_code(l):
    a,b = l.strip().split("\t")
    # remove redundant white spaces
    a = " ".join(a.split())
    print(a,'--->', b)
    return tuple(int(o) for o in a.split(' ')), b

# %%
label_codes,label_names = zip(*[parse_code(l) for l in open(PATH+"label_colors.txt")])
# Out:
# 64 128 64 ---> Animal
# 192 0 128 ---> Archway
# 0 128 192 ---> Bicyclist
# 0 128 64 ---> Bridge
# 128 0 0 ---> Building
# 64 0 128 ---> Car
# 64 0 192 ---> CartLuggagePram
# 192 128 64 ---> Child
# 192 192 128 ---> Column_Pole
# 64 64 128 ---> Fence
# 128 0 192 ---> LaneMkgsDriv
# 192 0 64 ---> LaneMkgsNonDriv
# 128 128 64 ---> Misc_Text
# 192 0 192 ---> MotorcycleScooter
# 128 64 64 ---> OtherMoving
# 64 192 128 ---> ParkingBlock
# 64 64 0 ---> Pedestrian
# 128 64 128 ---> Road
# 128 128 192 ---> RoadShoulder
# 0 0 192 ---> Sidewalk
# 192 128 128 ---> SignSymbol
# 128 128 128 ---> Sky
# 64 128 192 ---> SUVPickupTruck
# 0 0 64 ---> TrafficCone
# 0 64 64 ---> TrafficLight
# 192 64 128 ---> Train
# 128 128 0 ---> Tree
# 192 128 192 ---> Truck_Bus
# 64 0 64 ---> Tunnel
# 192 192 0 ---> VegetationMisc
# 0 0 0 ---> Void
# 64 192 0 ---> Wall

# %%
label_codes,label_names = list(label_codes),list(label_names)

# %%
list(zip(label_codes,label_names))[:5]
# Out:
# [((64, 128, 64), 'Animal'),
#  ((192, 0, 128), 'Archway'),
#  ((0, 128, 192), 'Bicyclist'),
#  ((0, 128, 64), 'Bridge'),
#  ((128, 0, 0), 'Building')]

# %% [markdown]
# We're going to map each unique pixel color to an integer so we can classify w/ our NN

# %%
code2id = {v:k for k,v in enumerate(label_codes)}

# %% [markdown]
# We'll include an integer for erroneous pixel values.

# %%
failed_code = len(label_codes)+1

# %%
label_codes.append((0,0,0))
label_names.append('unk')

# %%
def conv_one_label(i): 
    res = np.zeros((r,c), 'uint8')
    for j in range(r): 
        for k in range(c):
            try: res[j,k] = code2id[tuple(labels[i,j,k])]
            except: res[j,k] = failed_code
    return res

# %%
from concurrent.futures import ProcessPoolExecutor

# %%
def conv_all_labels():
    ex = ProcessPoolExecutor(8)
    return np.stack(ex.map(conv_one_label, range(n)))

# %% [markdown]
# Now we'll create integer-mapped labels for all our colored images.

# %%
# %time labels_int =conv_all_labels()
# Out:
# CPU times: user 372 ms, sys: 132 ms, total: 504 ms
# Wall time: 3min 13s

# %%
np.count_nonzero(labels_int==failed_code)
# Out:
# 44

# %% [markdown]
# Set erroneous pixels to zero.

# %%
labels_int.shape
# Out:
# (701, 360, 480)

# %%
labels_int[labels_int==failed_code]=0

# %%
save_array(PATH+results_directory+'/labels_int.bc', labels_int)

# %%
labels_int = load_array(PATH+results_directory+'/labels_int.bc')

# %%
sg = segm_generator(imgs, labels, 4, train=True)
b_img, b_label = next(sg)
plt.imshow(b_img[0]*0.3+0.4);

# %% [markdown]
# Here is an example of how the segmented image looks.

# %%
plt.imshow(b_label[0].reshape(nrows,ncols,nchs));

# %% [markdown]
# ### 2.3 Split training set and test set

# %% [markdown]
# Next we load test set, set training/test images and labels.

# %%
trn = imgs[0:468]
trn_labels = labels_int[0:468]
test = imgs[468:701]
test_labels = labels_int[468:701]
trn.shape, trn_labels.shape, test.shape, test_labels.shape
# Out:
# ((468, 360, 480, 3), (468, 360, 480), (233, 360, 480, 3), (233, 360, 480))

# %%
rnd_trn = len(trn_labels)
rnd_test = len(test_labels)

# %% [markdown]
# ## 3. Build "Fully Convolutional DenseNet56 "

# %% [markdown]
# ### 3.1 Helper functions

# %%
def relu(x): return Activation('relu')(x)
def dropout(x, p): return Dropout(p)(x) if p else x
def bn(x): return BatchNormalization( axis=-1)(x)
def relu_bn(x): return relu(bn(x))
def concat(xs): return concatenate(xs, axis=-1)

# %%
def conv(x, nf, sz, wd, p, stride=1): 
    x = Conv2D(nf, sz, kernel_initializer='he_uniform', padding='same', 
                      strides=(stride,stride), kernel_regularizer=l2(wd))(x)
    return dropout(x, p)

def conv_relu_bn(x, nf, sz=3, wd=0, p=0, stride=1): 
    return conv(relu_bn(x), nf, sz, wd=wd, p=p, stride=stride)

# %% [markdown]
# Recall the dense block from DenseNet.

# %%
def dense_block(n,x,growth_rate,p,wd):
    added = []
    for i in range(n):
        b = conv_relu_bn(x, growth_rate, p=p, wd=wd)
        x = concat([x, b])
        added.append(b)
    return x,added

# %% [markdown]
# This is the downsampling transition.
#
# In the original paper, downsampling consists of 1x1 convolution followed by max pooling. However we've found a stride 2 1x1 convolution to give better results.

# %%
def transition_dn(x, p, wd):
#     x = conv_relu_bn(x, x.get_shape().as_list()[-1], sz=1, p=p, wd=wd)
#     return MaxPooling2D(strides=(2, 2))(x)
    return conv_relu_bn(x, x.get_shape().as_list()[-1], sz=1, p=p, wd=wd, stride=2)

# %% [markdown]
# Next we build the entire downward path, keeping track of Dense block outputs in a list called `skip`.

# %%
def down_path(x, nb_layers, growth_rate, p, wd):
    skips = []
    for i,n in enumerate(nb_layers):
        x,added = dense_block(n,x,growth_rate,p,wd)
        skips.append(x)
        x = transition_dn(x, p=p, wd=wd)
    return skips, added

# %% [markdown]
# This is the upsampling transition. We use a transpose convolution layer.

# %%
def transition_up(added, wd=0):
    x = concat(added)
    _,r,c,ch = x.get_shape().as_list()
    return Conv2DTranspose(ch, 3,  kernel_initializer='he_uniform', 
               padding='same', strides=(2,2), kernel_regularizer=l2(wd))(x)
#     x = UpSampling2D()(x)
#     return conv(x, ch, 2, wd, 0)

# %% [markdown]
# This builds our upward path, concatenating the skip connections from `skip` to the Dense block inputs.

# %%
def up_path(added, skips, nb_layers, growth_rate, p, wd):
    for i,n in enumerate(nb_layers):
        x = transition_up(added, wd)
        x = concat([x,skips[i]])
        x,added = dense_block(n,x,growth_rate,p,wd)
    return x

# %% [markdown]
# ### 3.2 Build the model

# %% [markdown]
# - nb_classes: number of classes
# - img_input: tuple of shape (channels, rows, columns) or (rows, columns, channels)
# - nb_dense_block: number of dense blocks to add
# - growth_rate: number of filters to add per dense block
# - nb_filter:  initial number of filters
# - nb_layers_per_block: number of layers in each dense block.
#   - If positive integer, a set number of layers per dense block.
#   - If list, nb_layer is used as provided
# - p: dropout rate
# - wd: weight decay

# %%
def reverse(a): return list(reversed(a))

# %% [markdown]
# Finally we put together the entire network.

# %%
def create_tiramisu(nb_classes, img_input, nb_dense_block=6, 
    growth_rate=12, nb_filter=48, nb_layers_per_block=4, p=None, wd=0):
    
    if type(nb_layers_per_block) is list or type(nb_layers_per_block) is tuple:
        nb_layers = list(nb_layers_per_block)
    else: nb_layers = [nb_layers_per_block] * nb_dense_block

    x = conv(img_input, nb_filter, 3, wd, 0)
    skips,added = down_path(x, nb_layers, growth_rate, p, wd)
    x = up_path(added, reverse(skips[:-1]), reverse(nb_layers[:-1]), growth_rate, p, wd)
    
    x = conv(x, nb_classes, 1, wd, 0)
    _,r,c,f = x.get_shape().as_list()
    x = Reshape((-1, nb_classes))(x)
    return Activation('softmax')(x)

# %% [markdown]
# ## 4. Train the model

# %% [markdown]
# ### 4.1 Training on argumented images

# %%
#
#img_input = Input(shape=input_shape)

#x = create_tiramisu(33, img_input, nb_layers_per_block=4, p=0.2, wd=1e-4)
#import Tiramisu
#model = Tiramisu.create_tiramisu(33, img_input, nb_layers_per_block=4, p=0.2, wd=1e-4)

# %%
import Linknet
model = Linknet.LinkNet(input_shape, classes=33)
# Out:
# using net Linknet

# %%
#
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 128, 128, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 64, 64)   256         max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 64, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 64)   4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 64)   36928       activation_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 64)   0           conv2d_4[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 64)   256         add_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 64)   36928       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 64)   36928       activation_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 64)   0           add_1[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 64)   256         add_2[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 128)  73856       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 128)  8320        add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 128)  147584      activation_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 128)  0           conv2d_9[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 128)  512         add_3[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 128)  147584      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 128)  512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 128)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 128)  147584      activation_9[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 128)  0           add_3[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 128)  512         add_4[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 128)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 8, 256)    295168      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 8, 8, 256)    1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 8, 8, 256)    0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 256)    33024       add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 256)    590080      activation_11[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 8, 256)    0           conv2d_14[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 8, 8, 256)    1024        add_5[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 8, 8, 256)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 256)    590080      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 8, 8, 256)    1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 8, 8, 256)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 256)    590080      activation_13[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 8, 8, 256)    0           add_5[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 8, 256)    1024        add_6[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 8, 256)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 4, 4, 512)    1180160     activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 4, 4, 512)    2048        conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 4, 4, 512)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 4, 4, 512)    131584      add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 4, 4, 512)    2359808     activation_15[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 4, 4, 512)    0           conv2d_19[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 4, 4, 512)    2048        add_7[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 4, 4, 512)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 4, 4, 512)    2359808     activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 4, 4, 512)    2048        conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 4, 4, 512)    0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 4, 4, 512)    2359808     activation_17[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 4, 4, 512)    0           add_7[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 4, 4, 512)    2048        add_8[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 4, 4, 512)    0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 4, 4, 128)    65664       activation_18[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 8, 8, 128)    0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 8, 8, 128)    512         up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 8, 8, 128)    0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 8, 8, 128)    147584      activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 8, 8, 128)    512         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 8, 8, 128)    0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 8, 8, 256)    33024       activation_20[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 512)    0           conv2d_24[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 8, 8, 512)    0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 8, 8, 512)    2048        activation_21[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 8, 8, 512)    0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 8, 8, 64)     32832       activation_22[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 16, 16, 64)   0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 16, 16, 64)   256         up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 16, 16, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 16, 16, 64)   36928       activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 16, 16, 64)   256         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 16, 16, 64)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 16, 16, 128)  8320        activation_24[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 16, 16, 256)  0           conv2d_27[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 16, 16, 256)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 16, 16, 256)  1024        activation_25[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 16, 16, 256)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 16, 16, 32)   8224        activation_26[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 32, 32, 32)   0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 32, 32, 32)   128         up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 32, 32, 32)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 32, 32, 32)   9248        activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 32, 32, 32)   128         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 32, 32, 32)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 32, 32, 64)   2112        activation_28[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 32, 32, 128)  0           conv2d_30[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 32, 32, 128)  0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 32, 32, 128)  512         activation_29[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 32, 32, 128)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 32, 32, 16)   2064        activation_30[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 64, 64, 16)   0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 64, 64, 16)   64          up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 64, 64, 16)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 64, 64, 16)   2320        activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 64, 64, 16)   64          conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 64, 64, 16)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 64, 64, 64)   1088        activation_32[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 128, 128, 64) 0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 128, 128, 64) 256         up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 128, 128, 64) 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 128, 128, 32) 18464       activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 128, 128, 32) 128         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 128, 128, 32) 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 128, 128, 32) 9248        activation_34[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 256, 256, 32) 0           conv2d_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 256, 256, 32) 128         up_sampling2d_6[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 256, 256, 32) 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 256, 256, 33) 4257        activation_35[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 65536, 33)    0           conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 65536, 33)    0           reshape_1[0][0]
# ==================================================================================================
# Total params: 11,579,137
# Trainable params: 11,568,193
# Non-trainable params: 10,944
# __________________________________________________________________________________________________

# %%
gen = segm_generator(trn, trn_labels, 3, train=True)

# %%
gen_test = segm_generator(test, test_labels, 3, train=False)

# %%
model.compile(loss='sparse_categorical_crossentropy',  optimizer=keras.optimizers.RMSprop(1e-3), metrics=["accuracy"])

# %%
# directory for snapshots
snapshots_directory="snapshots"
try:
    os.stat(snapshots_directory)
except:
    os.mkdir(snapshots_directory)
    
filepath=snapshots_directory+'/tiramisu.{epoch:02d}-{val_acc:.2f}.hdf5'
mc_cb = keras.callbacks.ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=False, mode='max')

# %%
model.optimizer=keras.optimizers.RMSprop(1e-3, decay=1-0.99995)

# %% [markdown]
# To obtain accuracy over 85%,  it may take more than 24-48 hours (50-100 epochs) when you use Mac air (without GPU)
# Please look at http://www.toshistats.net/deep-learning-blog/2017/8/12/this-is-incredible-semantic-segmentation-by-just-700-images-from-scratch-with-mac-air

# %%
batch_size=10
epochs=100

import time
t=time.time()  

history=model.fit_generator(gen, rnd_trn//batch_size,  epochs, verbose=2,
                    validation_data=gen_test, validation_steps=rnd_test//batch_size, callbacks=[mc_cb])

t2 = time.time()
print(round(t2-t, 5), 'Seconds to predict')

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['loss', 'val_loss'], loc='upper right')
plt.show()
# Out:
# Epoch 1/100
#
# Epoch 00001: val_acc improved from -inf to 0.44210, saving model to snapshots/tiramisu.01-0.44.hdf5
#  - 23s - loss: 2.0572 - acc: 0.5125 - val_loss: 2.3066 - val_acc: 0.4421
# Epoch 2/100
#
# Epoch 00002: val_acc did not improve
#  - 16s - loss: 1.5871 - acc: 0.5840 - val_loss: 8.6873 - val_acc: 0.0829
# Epoch 3/100
#
# Epoch 00003: val_acc did not improve
#  - 16s - loss: 1.4735 - acc: 0.5961 - val_loss: 2.6833 - val_acc: 0.3668
# Epoch 4/100
#
# Epoch 00004: val_acc improved from 0.44210 to 0.66122, saving model to snapshots/tiramisu.04-0.66.hdf5
#  - 16s - loss: 1.3333 - acc: 0.6403 - val_loss: 1.3741 - val_acc: 0.6612
# Epoch 5/100
#
# Epoch 00005: val_acc improved from 0.66122 to 0.68132, saving model to snapshots/tiramisu.05-0.68.hdf5
#  - 16s - loss: 1.3339 - acc: 0.6361 - val_loss: 1.2634 - val_acc: 0.6813
# Epoch 6/100
#
# Epoch 00006: val_acc did not improve
#  - 16s - loss: 1.3126 - acc: 0.6435 - val_loss: 2.1134 - val_acc: 0.4255
# Epoch 7/100
#
# Epoch 00007: val_acc did not improve
#  - 16s - loss: 1.1553 - acc: 0.6840 - val_loss: 1.3370 - val_acc: 0.6593
# Epoch 8/100
#
# Epoch 00008: val_acc improved from 0.68132 to 0.70830, saving model to snapshots/tiramisu.08-0.71.hdf5
#  - 16s - loss: 1.1974 - acc: 0.6713 - val_loss: 1.0716 - val_acc: 0.7083
# Epoch 9/100
#
# Epoch 00009: val_acc did not improve
#  - 16s - loss: 1.0931 - acc: 0.7037 - val_loss: 1.2851 - val_acc: 0.6612
# Epoch 10/100
#
# Epoch 00010: val_acc improved from 0.70830 to 0.72633, saving model to snapshots/tiramisu.10-0.73.hdf5
#  - 16s - loss: 1.1292 - acc: 0.6942 - val_loss: 1.0480 - val_acc: 0.7263
# Epoch 11/100
#
# Epoch 00011: val_acc did not improve
#  - 16s - loss: 1.0909 - acc: 0.7022 - val_loss: 1.0797 - val_acc: 0.7197
# Epoch 12/100
#
# Epoch 00012: val_acc did not improve
#  - 16s - loss: 1.0297 - acc: 0.7187 - val_loss: 1.1232 - val_acc: 0.6964
# Epoch 13/100
#
# Epoch 00013: val_acc did not improve
#  - 16s - loss: 1.0034 - acc: 0.7319 - val_loss: 1.3731 - val_acc: 0.6634
# Epoch 14/100
#
# Epoch 00014: val_acc improved from 0.72633 to 0.72678, saving model to snapshots/tiramisu.14-0.73.hdf5
#  - 16s - loss: 0.9832 - acc: 0.7234 - val_loss: 1.0214 - val_acc: 0.7268
# Epoch 15/100
#
# Epoch 00015: val_acc improved from 0.72678 to 0.74677, saving model to snapshots/tiramisu.15-0.75.hdf5
#  - 16s - loss: 0.9441 - acc: 0.7376 - val_loss: 0.9440 - val_acc: 0.7468
# Epoch 16/100
#
# Epoch 00016: val_acc did not improve
#  - 16s - loss: 1.0147 - acc: 0.7235 - val_loss: 1.0101 - val_acc: 0.7356
# Epoch 17/100
#
# Epoch 00017: val_acc did not improve
#  - 16s - loss: 0.9216 - acc: 0.7398 - val_loss: 1.3886 - val_acc: 0.6412
# Epoch 18/100
#
# Epoch 00018: val_acc improved from 0.74677 to 0.74764, saving model to snapshots/tiramisu.18-0.75.hdf5
#  - 16s - loss: 0.8991 - acc: 0.7528 - val_loss: 0.8981 - val_acc: 0.7476
# Epoch 19/100
#
# Epoch 00019: val_acc did not improve
#  - 16s - loss: 0.9577 - acc: 0.7308 - val_loss: 1.2254 - val_acc: 0.6816
# Epoch 20/100
#
# Epoch 00020: val_acc did not improve
#  - 16s - loss: 0.9057 - acc: 0.7511 - val_loss: 1.0794 - val_acc: 0.7081
# Epoch 21/100
#
# Epoch 00021: val_acc did not improve
#  - 16s - loss: 0.9094 - acc: 0.7456 - val_loss: 1.1038 - val_acc: 0.7246
# Epoch 22/100
#
# Epoch 00022: val_acc improved from 0.74764 to 0.77534, saving model to snapshots/tiramisu.22-0.78.hdf5
#  - 16s - loss: 0.9077 - acc: 0.7459 - val_loss: 0.8490 - val_acc: 0.7753
# Epoch 23/100
#
# Epoch 00023: val_acc did not improve
#  - 16s - loss: 0.8749 - acc: 0.7555 - val_loss: 1.1490 - val_acc: 0.6980
# Epoch 24/100
#
# Epoch 00024: val_acc did not improve
#  - 16s - loss: 0.8523 - acc: 0.7587 - val_loss: 0.8980 - val_acc: 0.7642
# Epoch 25/100
#
# Epoch 00025: val_acc did not improve
#  - 16s - loss: 0.8559 - acc: 0.7589 - val_loss: 1.0183 - val_acc: 0.7246
# Epoch 26/100
#
# Epoch 00026: val_acc did not improve
#  - 16s - loss: 0.8833 - acc: 0.7559 - val_loss: 1.2736 - val_acc: 0.7036
# Epoch 27/100
#
# Epoch 00027: val_acc did not improve
#  - 16s - loss: 0.8316 - acc: 0.7693 - val_loss: 0.9931 - val_acc: 0.7259
# Epoch 28/100
#
# Epoch 00028: val_acc did not improve
#  - 16s - loss: 0.8580 - acc: 0.7598 - val_loss: 0.9487 - val_acc: 0.7600
# Epoch 29/100
#
# Epoch 00029: val_acc did not improve
#  - 16s - loss: 0.8176 - acc: 0.7730 - val_loss: 0.9528 - val_acc: 0.7475
# Epoch 30/100
#
# Epoch 00030: val_acc did not improve
#  - 16s - loss: 0.8221 - acc: 0.7650 - val_loss: 1.0997 - val_acc: 0.6949
# Epoch 31/100
#
# Epoch 00031: val_acc improved from 0.77534 to 0.79786, saving model to snapshots/tiramisu.31-0.80.hdf5
#  - 16s - loss: 0.7652 - acc: 0.7849 - val_loss: 0.7054 - val_acc: 0.7979
# Epoch 32/100
#
# Epoch 00032: val_acc did not improve
#  - 16s - loss: 0.8078 - acc: 0.7727 - val_loss: 0.9194 - val_acc: 0.7394
# Epoch 33/100
#
# Epoch 00033: val_acc did not improve
#  - 16s - loss: 0.7732 - acc: 0.7839 - val_loss: 0.9411 - val_acc: 0.7345
# Epoch 34/100
#
# Epoch 00034: val_acc did not improve
#  - 16s - loss: 0.8109 - acc: 0.7647 - val_loss: 0.8927 - val_acc: 0.7342
# Epoch 35/100
#
# Epoch 00035: val_acc did not improve
#  - 16s - loss: 0.7544 - acc: 0.7838 - val_loss: 0.7590 - val_acc: 0.7867
# Epoch 36/100
#
# Epoch 00036: val_acc did not improve
#  - 16s - loss: 0.7347 - acc: 0.7907 - val_loss: 1.2994 - val_acc: 0.6946
# Epoch 37/100
#
# Epoch 00037: val_acc did not improve
#  - 16s - loss: 0.7797 - acc: 0.7795 - val_loss: 0.8442 - val_acc: 0.7621
# Epoch 38/100
#
# Epoch 00038: val_acc did not improve
#  - 16s - loss: 0.7562 - acc: 0.7860 - val_loss: 0.9087 - val_acc: 0.7644
# Epoch 39/100
#
# Epoch 00039: val_acc did not improve
#  - 16s - loss: 0.7177 - acc: 0.7970 - val_loss: 0.7577 - val_acc: 0.7875
# Epoch 40/100
#
# Epoch 00040: val_acc did not improve
#  - 16s - loss: 0.7415 - acc: 0.7871 - val_loss: 0.9495 - val_acc: 0.7501
# Epoch 41/100
#
# Epoch 00041: val_acc did not improve
#  - 16s - loss: 0.7158 - acc: 0.7975 - val_loss: 0.7425 - val_acc: 0.7906
# Epoch 42/100
#
# Epoch 00042: val_acc improved from 0.79786 to 0.80902, saving model to snapshots/tiramisu.42-0.81.hdf5
#  - 16s - loss: 0.6881 - acc: 0.8027 - val_loss: 0.6951 - val_acc: 0.8090
# Epoch 43/100
#
# Epoch 00043: val_acc did not improve
#  - 16s - loss: 0.6886 - acc: 0.8055 - val_loss: 0.9620 - val_acc: 0.7431
# Epoch 44/100
#
# Epoch 00044: val_acc did not improve
#  - 16s - loss: 0.7446 - acc: 0.7865 - val_loss: 0.7038 - val_acc: 0.7982
# Epoch 45/100
#
# Epoch 00045: val_acc did not improve
#  - 16s - loss: 0.7125 - acc: 0.7982 - val_loss: 0.7236 - val_acc: 0.8012
# Epoch 46/100
#
# Epoch 00046: val_acc did not improve
#  - 16s - loss: 0.7120 - acc: 0.7991 - val_loss: 1.1124 - val_acc: 0.6818
# Epoch 47/100
#
# Epoch 00047: val_acc did not improve
#  - 16s - loss: 0.6680 - acc: 0.8097 - val_loss: 1.0677 - val_acc: 0.7152
# Epoch 48/100
#
# Epoch 00048: val_acc did not improve
#  - 16s - loss: 0.6782 - acc: 0.8057 - val_loss: 0.8400 - val_acc: 0.7667
# Epoch 49/100
#
# Epoch 00049: val_acc did not improve
#  - 16s - loss: 0.7212 - acc: 0.7973 - val_loss: 0.8426 - val_acc: 0.7699
# Epoch 50/100
#
# Epoch 00050: val_acc did not improve
#  - 16s - loss: 0.7263 - acc: 0.7932 - val_loss: 0.8431 - val_acc: 0.7607
# Epoch 51/100
#
# Epoch 00051: val_acc did not improve
#  - 16s - loss: 0.6550 - acc: 0.8150 - val_loss: 0.8414 - val_acc: 0.7730
# Epoch 52/100
#
# Epoch 00052: val_acc improved from 0.80902 to 0.81452, saving model to snapshots/tiramisu.52-0.81.hdf5
#  - 16s - loss: 0.7083 - acc: 0.7965 - val_loss: 0.6934 - val_acc: 0.8145
# Epoch 53/100
#
# Epoch 00053: val_acc did not improve
#  - 16s - loss: 0.7018 - acc: 0.8092 - val_loss: 1.0291 - val_acc: 0.7216
# Epoch 54/100
#
# Epoch 00054: val_acc did not improve
#  - 16s - loss: 0.6613 - acc: 0.8101 - val_loss: 0.7571 - val_acc: 0.7915
# Epoch 55/100
#
# Epoch 00055: val_acc improved from 0.81452 to 0.82923, saving model to snapshots/tiramisu.55-0.83.hdf5
#  - 16s - loss: 0.6968 - acc: 0.8002 - val_loss: 0.6161 - val_acc: 0.8292
# Epoch 56/100
#
# Epoch 00056: val_acc did not improve
#  - 16s - loss: 0.6697 - acc: 0.8046 - val_loss: 0.9000 - val_acc: 0.7622
# Epoch 57/100
#
# Epoch 00057: val_acc did not improve
#  - 16s - loss: 0.6617 - acc: 0.8116 - val_loss: 0.9664 - val_acc: 0.7417
# Epoch 58/100
#
# Epoch 00058: val_acc did not improve
#  - 16s - loss: 0.6338 - acc: 0.8181 - val_loss: 0.8309 - val_acc: 0.7728
# Epoch 59/100
#
# Epoch 00059: val_acc did not improve
#  - 16s - loss: 0.6614 - acc: 0.8129 - val_loss: 0.7546 - val_acc: 0.7982
# Epoch 60/100
#
# Epoch 00060: val_acc did not improve
#  - 16s - loss: 0.6495 - acc: 0.8110 - val_loss: 0.8379 - val_acc: 0.7661
# Epoch 61/100
#
# Epoch 00061: val_acc did not improve
#  - 16s - loss: 0.6991 - acc: 0.7988 - val_loss: 1.2053 - val_acc: 0.7248
# Epoch 62/100
#
# Epoch 00062: val_acc did not improve
#  - 16s - loss: 0.6374 - acc: 0.8187 - val_loss: 0.6487 - val_acc: 0.8264
# Epoch 63/100
#
# Epoch 00063: val_acc did not improve
#  - 16s - loss: 0.6571 - acc: 0.8132 - val_loss: 1.2126 - val_acc: 0.7525
# Epoch 64/100
#
# Epoch 00064: val_acc did not improve
#  - 16s - loss: 0.6250 - acc: 0.8169 - val_loss: 0.8771 - val_acc: 0.7566
# Epoch 65/100
#
# Epoch 00065: val_acc did not improve
#  - 16s - loss: 0.6597 - acc: 0.8084 - val_loss: 0.6845 - val_acc: 0.8110
# Epoch 66/100
#
# Epoch 00066: val_acc did not improve
#  - 16s - loss: 0.6289 - acc: 0.8183 - val_loss: 0.6997 - val_acc: 0.8072
# Epoch 67/100
#
# Epoch 00067: val_acc did not improve
#  - 16s - loss: 0.5942 - acc: 0.8256 - val_loss: 1.2332 - val_acc: 0.7135
# Epoch 68/100
#
# Epoch 00068: val_acc did not improve
#  - 16s - loss: 0.6545 - acc: 0.8162 - val_loss: 0.8851 - val_acc: 0.7747
# Epoch 69/100
#
# Epoch 00069: val_acc improved from 0.82923 to 0.84093, saving model to snapshots/tiramisu.69-0.84.hdf5
#  - 16s - loss: 0.6220 - acc: 0.8214 - val_loss: 0.5838 - val_acc: 0.8409
# Epoch 70/100
#
# Epoch 00070: val_acc did not improve
#  - 16s - loss: 0.6502 - acc: 0.8096 - val_loss: 0.9884 - val_acc: 0.7431
# Epoch 71/100
#
# Epoch 00071: val_acc did not improve
#  - 16s - loss: 0.6344 - acc: 0.8173 - val_loss: 0.6888 - val_acc: 0.8048
# Epoch 72/100
#
# Epoch 00072: val_acc did not improve
#  - 16s - loss: 0.5611 - acc: 0.8361 - val_loss: 1.1292 - val_acc: 0.7427
# Epoch 73/100
#
# Epoch 00073: val_acc did not improve
#  - 16s - loss: 0.6002 - acc: 0.8303 - val_loss: 0.6760 - val_acc: 0.8045
# Epoch 74/100
#
# Epoch 00074: val_acc did not improve
#  - 16s - loss: 0.6424 - acc: 0.8144 - val_loss: 0.9239 - val_acc: 0.7592
# Epoch 75/100
#
# Epoch 00075: val_acc did not improve
#  - 16s - loss: 0.6067 - acc: 0.8257 - val_loss: 0.7320 - val_acc: 0.7876
# Epoch 76/100
#
# Epoch 00076: val_acc did not improve
#  - 16s - loss: 0.6260 - acc: 0.8189 - val_loss: 0.6197 - val_acc: 0.8279
# Epoch 77/100
#
# Epoch 00077: val_acc did not improve
#  - 16s - loss: 0.6419 - acc: 0.8160 - val_loss: 0.9863 - val_acc: 0.7473
# Epoch 78/100
#
# Epoch 00078: val_acc did not improve
#  - 16s - loss: 0.6417 - acc: 0.8184 - val_loss: 0.8544 - val_acc: 0.7791
# Epoch 79/100
#
# Epoch 00079: val_acc improved from 0.84093 to 0.84596, saving model to snapshots/tiramisu.79-0.85.hdf5
#  - 16s - loss: 0.6087 - acc: 0.8231 - val_loss: 0.5370 - val_acc: 0.8460
# Epoch 80/100
#
# Epoch 00080: val_acc did not improve
#  - 16s - loss: 0.6309 - acc: 0.8132 - val_loss: 0.6561 - val_acc: 0.8146
# Epoch 81/100
#
# Epoch 00081: val_acc did not improve
#  - 16s - loss: 0.5863 - acc: 0.8316 - val_loss: 0.9066 - val_acc: 0.7664
# Epoch 82/100
#
# Epoch 00082: val_acc did not improve
#  - 16s - loss: 0.5765 - acc: 0.8330 - val_loss: 0.5705 - val_acc: 0.8382
# Epoch 83/100
#
# Epoch 00083: val_acc did not improve
#  - 16s - loss: 0.5648 - acc: 0.8351 - val_loss: 0.7245 - val_acc: 0.8115
# Epoch 84/100
#
# Epoch 00084: val_acc did not improve
#  - 16s - loss: 0.6113 - acc: 0.8267 - val_loss: 0.7860 - val_acc: 0.7831
# Epoch 85/100
#
# Epoch 00085: val_acc did not improve
#  - 16s - loss: 0.6143 - acc: 0.8179 - val_loss: 0.7243 - val_acc: 0.7990
# Epoch 86/100
#
# Epoch 00086: val_acc did not improve
#  - 16s - loss: 0.5416 - acc: 0.8411 - val_loss: 0.5513 - val_acc: 0.8399
# Epoch 87/100
#
# Epoch 00087: val_acc did not improve
#  - 16s - loss: 0.6240 - acc: 0.8199 - val_loss: 0.7334 - val_acc: 0.7953
# Epoch 88/100
#
# Epoch 00088: val_acc did not improve
#  - 16s - loss: 0.5745 - acc: 0.8314 - val_loss: 0.6656 - val_acc: 0.8133
# Epoch 89/100
#
# Epoch 00089: val_acc did not improve
#  - 16s - loss: 0.5955 - acc: 0.8271 - val_loss: 0.5939 - val_acc: 0.8321
# Epoch 90/100
#
# Epoch 00090: val_acc did not improve
#  - 16s - loss: 0.5876 - acc: 0.8273 - val_loss: 0.8820 - val_acc: 0.7592
# Epoch 91/100
#
# Epoch 00091: val_acc did not improve
#  - 16s - loss: 0.5628 - acc: 0.8360 - val_loss: 0.8708 - val_acc: 0.7740
# Epoch 92/100
#
# Epoch 00092: val_acc did not improve
#  - 16s - loss: 0.5777 - acc: 0.8320 - val_loss: 0.8382 - val_acc: 0.7959
# Epoch 93/100
#
# Epoch 00093: val_acc did not improve
#  - 16s - loss: 0.5830 - acc: 0.8277 - val_loss: 0.5437 - val_acc: 0.8397
# Epoch 94/100
#
# Epoch 00094: val_acc did not improve
#  - 16s - loss: 0.5955 - acc: 0.8264 - val_loss: 1.0081 - val_acc: 0.7461
# Epoch 95/100
#
# Epoch 00095: val_acc did not improve
#  - 16s - loss: 0.5735 - acc: 0.8333 - val_loss: 0.7692 - val_acc: 0.7855
# Epoch 96/100
#
# Epoch 00096: val_acc improved from 0.84596 to 0.85799, saving model to snapshots/tiramisu.96-0.86.hdf5
#  - 16s - loss: 0.5660 - acc: 0.8334 - val_loss: 0.5042 - val_acc: 0.8580
# Epoch 97/100
#
# Epoch 00097: val_acc did not improve
#  - 16s - loss: 0.5916 - acc: 0.8282 - val_loss: 0.6162 - val_acc: 0.8211
# Epoch 98/100
#
# Epoch 00098: val_acc did not improve
#  - 16s - loss: 0.5498 - acc: 0.8361 - val_loss: 0.7979 - val_acc: 0.7629
# Epoch 99/100
#
# Epoch 00099: val_acc did not improve
#  - 16s - loss: 0.5908 - acc: 0.8294 - val_loss: 0.6795 - val_acc: 0.8068
# Epoch 100/100
#
# Epoch 00100: val_acc did not improve
#  - 16s - loss: 0.5449 - acc: 0.8376 - val_loss: 0.6088 - val_acc: 0.8248
# 1571.54574 Seconds to predict

# %% [markdown]
# ## 5. View results

# %% [markdown]
# ### 5.1 Import RGB data and names for each class

# %%
colors = [(64, 128, 64), (192, 0, 128), (0, 128, 192),(0, 128, 64), (128, 0, 0), (64, 0, 128), (64, 0, 192), (192, 128, 64), (192, 192, 128), (64, 64, 128),
 (128, 0, 192), (192, 0, 64), (128, 128, 64), (192, 0, 192), (128, 64, 64), (64, 192, 128), (64, 64, 0), (128, 64, 128), (128, 128, 192), (0, 0, 192),
(192, 128, 128), (128, 128, 128), (64, 128, 192), (0, 0, 64),(0 ,64, 64), (192, 64, 128), (128, 128, 0), (192, 128, 192), (64, 0, 64),(192, 192, 0),
 (0, 0, 0), (64, 192, 0)]

names = ['Animal', 'Archway', 'Bicyclist', 'Bridge', 'Building', 'Car','CartLuggagePram', 'Child', 'Column_Pole','Fence', 'LaneMkgsDriv', 
         'LaneMkgsNonDriv', 'Misc_Text', 'MotorcycleScooter', 'OtherMoving','ParkingBlock','Pedestrian','Road', 'RoadShoulder','RoadShoulder',
         'Sidewalk', 'SignSymbol','Sky', 'SUVPickupTruck','TrafficCone', 'TrafficLight','Train','Tree','Truck_Bus', 'Tunnel','VegetationMisc','Void',
         'Wall']

# %%
# get the last snapshot
import glob
snapshot_files=sorted(glob.glob(os.path.join(snapshots_directory, '*.hdf5')))
print(snapshot_files[-1])

# Import the model created above
from keras.models import load_model

model = load_model(snapshot_files[-1])
# Out:
# snapshots/tiramisu.96-0.86.hdf5

# %% [markdown]
# ### 5.2 view the result of exmaples

# %%
print(b_img.shape)
# Out:
# (4, 256, 256, 3)

# %%
i = 2
#
b = np.expand_dims(b_img[i], axis=0)
#print(np.shape(b))
print(b.shape)

p = model.predict(b)
#print(np.shape(p))
print(p.shape)

p = np.argmax(p[0],-1).reshape(nrows,ncols)
#print(np.shape(p))
print(p.shape)
# Out:
# (1, 256, 256, 3)
# (1, 65536, 33)
# (256, 256)

# %%
def color_label(p, r, c): 
    res = np.zeros((r,c,3), 'uint8')
    for j in range(r): 
        for k in range(c):
            res[j,k,:] = colors[p[j,k]]
    return res

# %%
r=nrows
c=ncols
pred = color_label(p, r, c)

# %%
# Show the sample images
bl=b_label[i].reshape(nrows,ncols,nchs)

imm=[(b_img[i]*0.3+0.4), bl, pred]
title=['original','ground-truth','prediction']
plt.figure(figsize=(20,15))

for i in range(len(imm)):
    plt.subplot(1,3, i+1)
    plt.imshow(imm[i]) 
    plt.title(title[i],fontsize=30)

# %% [markdown]
# Notice: TOSHI STATS SDN. BHD. and I do not accept any responsibility or liability for loss or damage occasioned to any person or property through using materials, instructions, methods, algorithm or ideas contained herein, or acting or refraining from acting as a result of such use. TOSHI STATS SDN. BHD. and I expressly disclaim all implied warranties, including merchantability or fitness for any particular purpose. There will be no duty on TOSHI STATS SDN. BHD. and me to correct any errors or defects in the codes and the software
